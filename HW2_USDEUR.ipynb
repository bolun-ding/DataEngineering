# %%
# setting the environment
## import necessary library and packages
import websocket
import json
import polygon
import sqlite3
import requests
import datetime
from datetime import datetime
import time
import time
import csv
import requests
import numpy as np
from datetime import datetime, timedelta
from sqlalchemy import create_engine, Column, Integer, String, Float, DateTime
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from pymongo import MongoClient

# %%
#MongoDB Setup
client = MongoClient('mongodb://localhost:27017/')
auxiliary = client['auxiliary']
mongo_fx_data_collection = auxiliary['auxiliary_data_USDEUR']

final_db = client['final_data']
mongo_fx_data_collection_final = final_db['final_data_USDEUR']

# %%
#Set up SQLite connection
BaseAuxiliary = declarative_base()
BaseFinal = declarative_base()

# Define classes for Auxiliary DB
class AuxiliaryData(BaseAuxiliary):
    __tablename__ = 'auxiliary_data_USDEUR'
    id = Column(Integer, primary_key=True)
    from_currency = Column(String)
    to_currency = Column(String)
    rate = Column(Float)
    data_timestamp = Column(String)
    rate_timestamp = Column(DateTime)
    max_rate = Column(Float)
    min_rate = Column(Float)
    mean_rate = Column(Float)
    vol = Column(Float)
    fd = Column(Float)

# create engine for Auxiliary DB
engine_auxiliary = create_engine('sqlite:///auxiliary_USDEUR.db')

# use engine_auxiliary to create table
BaseAuxiliary.metadata.create_all(engine_auxiliary)

#Define classes for Final DB
class FinalData(BaseFinal):
    __tablename__ = 'final_data_USDEUR'
    id = Column(Integer, primary_key=True)
    data_timestamp = Column(String)
    db_entry_timestamp = Column(String)
    max_rate = Column(Float)
    min_rate = Column(Float)
    mean_rate = Column(Float)
    vol = Column(Float)
    fd = Column(Float)

# create engine for Auxiliary DB
engine_final = create_engine('sqlite:///final_data_USDEUR.db')

# Use engine_final to create table
BaseFinal.metadata.create_all(engine_final)
# Out:
# /var/folders/yh/cq0k6g5s67vdhvshzm13h_gw0000gn/T/ipykernel_21883/700060366.py:2: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   BaseAuxiliary = declarative_base()
# /var/folders/yh/cq0k6g5s67vdhvshzm13h_gw0000gn/T/ipykernel_21883/700060366.py:3: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   BaseFinal = declarative_base()

# %%
#Define the function to get the data from Polygon API
API_KEY = 'beBybSi8daPgsTp5yx5cHtHpYcrjp5Jq'  
def get_real_time_fx_data(currency_from, currency_to, amount, precision):
    try:
        endpoint = f"https://api.polygon.io/v1/conversion/{currency_from}/{currency_to}?amount={amount}&precision={precision}&apiKey={API_KEY}"
        response = requests.get(endpoint)
        response.raise_for_status()  # Raises exception for HTTP errors
        data = response.json()

        if data['status'] == 'success':
            return {
                'data_timestamp': data['last']['timestamp'],
                'rate_timestamp' : datetime.now() ,  # Time of the request
                'rate': data['converted']
                # entry_timestamp will be set just before data entry
            }
        else:
            print("The conversion request was not successful.")
            return None
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# %%
#How to calculate FD
def calculate_fd(N, max_rate, min_rate):
    # Calculate FD using the formula
    different = max_rate - min_rate
    if different == 0:
        different = 1
    fd = N / different 

    return fd

# %%
def calculate_keltner_upper_bands(mean_value, vol):
    return [mean_value + n * 0.025 * vol for n in range(1, 101)]

# %%
def calculate_keltner_lower_bands(mean_value, vol):
    return [mean_value - n * 0.025 * vol for n in range(1, 101)]

# %%
#Main
def main():
    #Sqlite DB, AUX and FINAL
    Session = sessionmaker(bind=engine_auxiliary)
    session = Session()
    SessionFinal = sessionmaker(bind=engine_final)
    session_final = SessionFinal()

    #Set end time to 6 mins from now
    start_time = datetime.now()
    end_time = start_time + timedelta(seconds = 360)

    #Initial settings for feature
    max_rate = 0
    min_rate = float('inf')
    total_sum = 0
    count = 0
    fd = 0
    pre_vol = 1

#First Loop
    while datetime.now() < end_time:
        rate = get_real_time_fx_data('USD', 'EUR', 1, 4)
        current_time = datetime.now()
        print(rate)
        
        time.sleep(1)

        #update max, min, total_sum, count
        current_rate = rate['rate']
        if max_rate is None or current_rate > max_rate:
            max_rate = current_rate
        if min_rate is None or current_rate < min_rate:
            min_rate = current_rate

        total_sum += current_rate
        count += 1
        
        # Calculate mean and VOL
        mean_value = total_sum / count if count else 0
        vol = (max_rate - min_rate) / mean_value if mean_value else float('inf')

        #calculate mean and VOL
        fx_data = AuxiliaryData(
            data_timestamp = rate['data_timestamp'],
            rate_timestamp = datetime.now(),
            rate = current_rate,
            max_rate = max_rate,
            min_rate = min_rate,
            mean_rate = mean_value,
            vol = vol 
        )

        #Store data in MongoDB
        mongo_fx_data_collection.insert_one({
            'data_timestamp': rate['data_timestamp'],
            'timestamp': datetime.now(),
            'rate': rate,
            'max_rate': max_rate,
            'min_rate': min_rate,
            'mean_value': mean_value,
            'vol': vol
        })  
        session.add(fx_data)
        session.commit()

        # Store data in MongoDB
        mongo_fx_data_collection.insert_one({
            'data_timestamp': rate['data_timestamp'],
            'timestamp': datetime.now(),
            'rate': rate,
            'max_rate': max_rate,
            'min_rate': min_rate,
            'mean_value': mean_value,
            'vol': vol
        })

    #SQLite Record the time data entry into the FINAL DB
    entry_time = datetime.now()
    #Store the first loop data
    final_data = FinalData(
        data_timestamp = rate['data_timestamp'],
        db_entry_timestamp = entry_time,
        max_rate = max_rate,
        min_rate = min_rate,
        mean_rate = mean_value,
        vol = vol,
    )

    session_final.add(final_data)
    session_final.commit()

    #MongoDB Record the time data entry into the FINAL DB
    mongo_fx_data_collection_final.insert_one({
        'data_timestamp': start_time.isoformat(),
        'entry_timestamp': entry_time.isoformat(),
        'max_rate': max_rate,
        'min_rate': min_rate,
        'mean_rate': mean_value,
        'vol': vol
    })

    BaseAuxiliary.metadata.drop_all(engine_auxiliary)
    #Kill the Auxilary DB
    BaseAuxiliary.metadata.create_all(engine_auxiliary)
    mongo_fx_data_collection.delete_many({})

    #set vol to pre_vol for the calculation of next FD
    pre_vol = vol

    #End of the first loop

    print("===================End of first loop ===========================")
    print("max_rate:", max_rate)
    print("min_rate:", min_rate)
    print("mean_value:", mean_value)
    print("vol:", vol)

    #code for #2 to #50
    num_loop = 50
    for i in range(num_loop):
        #SQLite DB
        Session = sessionmaker(bind=engine_auxiliary)
        session = Session()
        SessionFinal = sessionmaker(bind=engine_final)
        session_final = SessionFinal()

        #run 6 mins
        start_time = datetime.now()
        end_time = start_time + timedelta(seconds = 360)

        #Initial settings for feature
        max_rate = 0
        min_rate = float('inf')
        total_sum = 0
        count = 0
        fd = 0
        pre_rate = 0
        N = 0
        #no vol since pre_vol is set in the first loop

        #Start of the loop
        while datetime.now() < end_time:
            rate = get_real_time_fx_data('USD', 'EUR', 1, 4)
            current_time = datetime.now()
            print(rate)

            time.sleep(1)

            #update max, min, total_sum, count
            current_rate = rate['rate']
            if max_rate is None or current_rate > max_rate:
                max_rate = current_rate
            if min_rate is None or current_rate < min_rate:
                min_rate = current_rate
            
            total_sum += current_rate
            count += 1
            
            #calculate FD
            fx_data = AuxiliaryData(
                data_timestamp = rate['data_timestamp'],
                rate_timestamp = datetime.now(),
                rate = current_rate,
                max_rate = max_rate,
                min_rate = min_rate,
                mean_rate = mean_value,
                vol = vol,
                fd = fd
            )

            #store data in MongoDB
            mongo_fx_data_collection.insert_one({
                'data_timestamp' : rate['data_timestamp'],
                'timestamp': datetime.now(),
                'rate': rate,
                'max_rate': max_rate,
                'min_rate': min_rate,
                'mean_value': mean_value,
                'vol': vol,
                'fd': fd
            })
        
        

        #calculate mean and VOL
        mean_value = total_sum / count if count else 0
        vol = (max_rate - min_rate) / mean_value if mean_value else float('inf')
                
        if i > 0:  # Calculate Keltner Upper Bands after the first period
            keltner_upper_bands = calculate_keltner_upper_bands(mean_value, pre_vol)
            print(f"Keltner Upper Bands for period {i}:")
            for n, upper_band in enumerate(keltner_upper_bands, start=1):
                print(f"n={n}, Upper Band={upper_band}")

        if i > 0:  # Calculate Keltner Upper Bands after the first period
            keltner_lower_bands = calculate_keltner_lower_bands(mean_value, pre_vol)
            print(f"Keltner Lower Bands for period {i}:")
            for n, lower_band in enumerate(keltner_upper_bands, start=1):
                print(f"n={n}, Lower Band={lower_band}")

        if vol == 0:
            vol = 1
        #trick to calculate N
        #N += abs(current_rate - pre_rate)/(0.025 * pre_vol + 1e-8)
        #Not sure, but I think N should be represented as 
        N += (current_rate - pre_rate)/(0.025)
        #set current rate to pre_rate for the next calculation
        pre_rate = current_rate
        
        fd = calculate_fd(N, max_rate, min_rate)

        #SQLite:time the data entry for the FINAL DB
        entry_time = datetime.now()

        final_data = FinalData(
            data_timestamp = str(start_time),
            db_entry_timestamp = str(entry_time),
            max_rate = max_rate,
            min_rate = min_rate,
            mean_rate = mean_value,
            vol = vol,
            fd = fd
        )
        session_final.add(final_data)
        session_final.commit()

        #MongoDB:time the data entry for the FINAL DB
        
        mongo_fx_data_collection_final.insert_one({
            'data_timestamp': start_time.isoformat(),
            'entry_timestamp': entry_time.isoformat(),
            'max_rate': max_rate,
            'min_rate': min_rate,
            'mean_rate': mean_value,
            'vol': vol,
            'fd': fd
        })

        print("Data has been saved to the Final DB (SQLite and MongoDB)")

        #reset the tables
        BaseAuxiliary.metadata.drop_all(engine_auxiliary)
        BaseAuxiliary.metadata.create_all(engine_auxiliary)
        mongo_fx_data_collection.delete_many({})

        #set vol to pre_vol for the calculation of next FD
        pre_vol = vol

        print("===================End of loop ===========================")
        print("Number of Loops:", i+1)
        print("Final fd:", fd)

#Convert the data to CSV
engine_final = create_engine('sqlite:///final_data_USDEUR.db')
Session = sessionmaker(bind=engine_final)
session = Session()

#find all the data
records_data = session.query(FinalData).all()

with open('final_data_USDEUR.csv', 'w', newline='') as csvfile:
    fieldnames = ['id', 'data_timestamp', 'db_entry_timestamp', 'max_rate', 'min_rate', 'mean_rate', 'vol', 'fd']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for record in records_data:
        writer.writerow({
            'id': record.id,
            'data_timestamp': record.data_timestamp,
            'db_entry_timestamp': record.db_entry_timestamp,
            'max_rate': record.max_rate,
            'min_rate': record.min_rate,
            'mean_rate': record.mean_rate,
            'vol': record.vol,
            'fd': record.fd
        })

session.close()

# %%
if __name__ == '__main__':
    main()
# Out:
# {'data_timestamp': 1717461992000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 34, 52848), 'rate': 0.9161}
# {'data_timestamp': 1717461992000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 35, 323736), 'rate': 0.9161}
# {'data_timestamp': 1717461992000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 36, 426929), 'rate': 0.9161}
# {'data_timestamp': 1717461992000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 37, 532899), 'rate': 0.9161}
# {'data_timestamp': 1717461998000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 38, 626726), 'rate': 0.9161}
# {'data_timestamp': 1717461998000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 39, 705047), 'rate': 0.9161}
# {'data_timestamp': 1717461998000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 40, 818359), 'rate': 0.9161}
# {'data_timestamp': 1717461998000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 41, 912740), 'rate': 0.9161}
# {'data_timestamp': 1717461998000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 43, 25095), 'rate': 0.9161}
# {'data_timestamp': 1717462002000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 44, 135888), 'rate': 0.9161}
# {'data_timestamp': 1717462002000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 45, 238611), 'rate': 0.9161}
# {'data_timestamp': 1717462005000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 46, 430577), 'rate': 0.9161}
# {'data_timestamp': 1717462005000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 47, 525739), 'rate': 0.9161}
# {'data_timestamp': 1717462007000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 48, 712457), 'rate': 0.9161}
# {'data_timestamp': 1717462009000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 49, 882619), 'rate': 0.9159}
# {'data_timestamp': 1717462010000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 50, 975602), 'rate': 0.9161}
# {'data_timestamp': 1717462011000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 52, 74823), 'rate': 0.9161}
# {'data_timestamp': 1717462012000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 53, 276814), 'rate': 0.9161}
# {'data_timestamp': 1717462014000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 54, 383649), 'rate': 0.9161}
# {'data_timestamp': 1717462014000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 55, 721435), 'rate': 0.9161}
# {'data_timestamp': 1717462014000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 56, 815782), 'rate': 0.9161}
# {'data_timestamp': 1717462016000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 57, 908545), 'rate': 0.9162}
# {'data_timestamp': 1717462016000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 46, 59, 32074), 'rate': 0.9162}
# {'data_timestamp': 1717462019000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 0, 130721), 'rate': 0.9162}
# {'data_timestamp': 1717462020000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 1, 234407), 'rate': 0.9162}
# {'data_timestamp': 1717462021000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 2, 350114), 'rate': 0.9162}
# {'data_timestamp': 1717462022000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 3, 462276), 'rate': 0.9162}
# {'data_timestamp': 1717462024000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 4, 716303), 'rate': 0.9159}
# {'data_timestamp': 1717462025000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 6, 4904), 'rate': 0.9162}
# {'data_timestamp': 1717462026000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 7, 109985), 'rate': 0.9162}
# {'data_timestamp': 1717462027000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 8, 214551), 'rate': 0.9162}
# {'data_timestamp': 1717462028000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 9, 324893), 'rate': 0.9162}
# {'data_timestamp': 1717462029000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 10, 456241), 'rate': 0.9162}
# {'data_timestamp': 1717462030000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 11, 574052), 'rate': 0.9162}
# {'data_timestamp': 1717462031000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 12, 680129), 'rate': 0.9162}
# {'data_timestamp': 1717462031000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 13, 800294), 'rate': 0.9162}
# {'data_timestamp': 1717462031000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 14, 922244), 'rate': 0.9162}
# {'data_timestamp': 1717462035000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 16, 130805), 'rate': 0.9162}
# {'data_timestamp': 1717462036000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 17, 216043), 'rate': 0.9162}
# {'data_timestamp': 1717462037000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 18, 329925), 'rate': 0.9162}
# {'data_timestamp': 1717462038000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 19, 480696), 'rate': 0.9162}
# {'data_timestamp': 1717462039000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 20, 629131), 'rate': 0.9162}
# {'data_timestamp': 1717462039000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 21, 742717), 'rate': 0.9162}
# {'data_timestamp': 1717462042000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 22, 845739), 'rate': 0.9162}
# {'data_timestamp': 1717462043000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 23, 943704), 'rate': 0.9162}
# {'data_timestamp': 1717462043000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 25, 111002), 'rate': 0.9162}
# {'data_timestamp': 1717462043000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 26, 293273), 'rate': 0.9162}
# {'data_timestamp': 1717462043000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 27, 393923), 'rate': 0.9162}
# {'data_timestamp': 1717462043000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 28, 514407), 'rate': 0.9162}
# {'data_timestamp': 1717462043000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 29, 850003), 'rate': 0.9162}
# {'data_timestamp': 1717462043000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 30, 966682), 'rate': 0.9162}
# {'data_timestamp': 1717462043000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 32, 60264), 'rate': 0.9162}
# {'data_timestamp': 1717462052000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 33, 168038), 'rate': 0.9162}
# {'data_timestamp': 1717462052000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 34, 274856), 'rate': 0.9162}
# {'data_timestamp': 1717462052000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 35, 389585), 'rate': 0.9162}
# {'data_timestamp': 1717462052000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 36, 521369), 'rate': 0.9162}
# {'data_timestamp': 1717462052000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 37, 639414), 'rate': 0.9162}
# {'data_timestamp': 1717462052000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 38, 742658), 'rate': 0.9162}
# {'data_timestamp': 1717462052000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 39, 845086), 'rate': 0.9162}
# {'data_timestamp': 1717462052000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 41, 96321), 'rate': 0.9162}
# {'data_timestamp': 1717462052000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 42, 210540), 'rate': 0.9162}
# {'data_timestamp': 1717462052000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 43, 489762), 'rate': 0.9162}
# {'data_timestamp': 1717462064000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 44, 610378), 'rate': 0.9162}
# {'data_timestamp': 1717462064000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 45, 726438), 'rate': 0.9162}
# {'data_timestamp': 1717462064000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 46, 870921), 'rate': 0.9162}
# {'data_timestamp': 1717462067000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 47, 976166), 'rate': 0.9162}
# {'data_timestamp': 1717462068000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 49, 98877), 'rate': 0.9162}
# {'data_timestamp': 1717462069000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 50, 212159), 'rate': 0.9162}
# {'data_timestamp': 1717462069000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 51, 314454), 'rate': 0.9162}
# {'data_timestamp': 1717462072000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 52, 441905), 'rate': 0.9162}
# {'data_timestamp': 1717462072000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 53, 556668), 'rate': 0.9162}
# {'data_timestamp': 1717462073000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 54, 735917), 'rate': 0.9162}
# {'data_timestamp': 1717462073000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 55, 883422), 'rate': 0.9162}
# {'data_timestamp': 1717462073000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 56, 989714), 'rate': 0.9162}
# {'data_timestamp': 1717462073000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 58, 86873), 'rate': 0.9162}
# {'data_timestamp': 1717462079000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 47, 59, 199215), 'rate': 0.9162}
# {'data_timestamp': 1717462079000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 0, 422558), 'rate': 0.9162}
# {'data_timestamp': 1717462081000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 1, 540115), 'rate': 0.9162}
# {'data_timestamp': 1717462081000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 2, 644952), 'rate': 0.9162}
# {'data_timestamp': 1717462083000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 3, 768278), 'rate': 0.9162}
# {'data_timestamp': 1717462083000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 4, 878879), 'rate': 0.9162}
# {'data_timestamp': 1717462084000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 5, 984380), 'rate': 0.9162}
# {'data_timestamp': 1717462084000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 7, 84612), 'rate': 0.9162}
# {'data_timestamp': 1717462087000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 8, 467178), 'rate': 0.9161}
# {'data_timestamp': 1717462089000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 9, 581167), 'rate': 0.9162}
# {'data_timestamp': 1717462090000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 10, 686263), 'rate': 0.9162}
# {'data_timestamp': 1717462090000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 11, 812968), 'rate': 0.9162}
# {'data_timestamp': 1717462090000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 12, 932354), 'rate': 0.9162}
# {'data_timestamp': 1717462093000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 14, 56794), 'rate': 0.9162}
# {'data_timestamp': 1717462094000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 15, 151203), 'rate': 0.9162}
# {'data_timestamp': 1717462094000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 16, 252800), 'rate': 0.9162}
# {'data_timestamp': 1717462094000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 17, 355861), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 18, 466202), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 19, 590047), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 20, 696846), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 21, 801453), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 22, 902948), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 24, 16516), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 25, 128571), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 26, 254990), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 27, 389963), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 28, 478689), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 29, 582309), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 30, 689100), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 31, 810932), 'rate': 0.9162}
# {'data_timestamp': 1717462098000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 32, 925106), 'rate': 0.9162}
# {'data_timestamp': 1717462112000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 34, 216910), 'rate': 0.9161}
# {'data_timestamp': 1717462114000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 35, 323441), 'rate': 0.9161}
# {'data_timestamp': 1717462114000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 36, 440097), 'rate': 0.9161}
# {'data_timestamp': 1717462116000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 37, 561691), 'rate': 0.9162}
# {'data_timestamp': 1717462116000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 38, 672422), 'rate': 0.9162}
# {'data_timestamp': 1717462116000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 39, 986325), 'rate': 0.9162}
# {'data_timestamp': 1717462116000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 41, 90313), 'rate': 0.9162}
# {'data_timestamp': 1717462116000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 42, 317825), 'rate': 0.9162}
# {'data_timestamp': 1717462116000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 43, 524471), 'rate': 0.9162}
# {'data_timestamp': 1717462116000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 44, 647171), 'rate': 0.9162}
# {'data_timestamp': 1717462116000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 45, 938527), 'rate': 0.9162}
# {'data_timestamp': 1717462116000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 47, 38134), 'rate': 0.9162}
# {'data_timestamp': 1717462127000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 48, 134068), 'rate': 0.9162}
# {'data_timestamp': 1717462128000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 49, 243197), 'rate': 0.9162}
# {'data_timestamp': 1717462129000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 50, 357666), 'rate': 0.9162}
# {'data_timestamp': 1717462130000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 51, 477042), 'rate': 0.9162}
# {'data_timestamp': 1717462130000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 52, 622775), 'rate': 0.9162}
# {'data_timestamp': 1717462130000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 53, 889065), 'rate': 0.9162}
# {'data_timestamp': 1717462130000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 55, 8265), 'rate': 0.9162}
# {'data_timestamp': 1717462135000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 56, 114998), 'rate': 0.9162}
# {'data_timestamp': 1717462135000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 57, 228337), 'rate': 0.9162}
# {'data_timestamp': 1717462135000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 58, 348574), 'rate': 0.9162}
# {'data_timestamp': 1717462135000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 48, 59, 460367), 'rate': 0.9162}
# {'data_timestamp': 1717462135000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 0, 570940), 'rate': 0.9162}
# {'data_timestamp': 1717462135000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 1, 677545), 'rate': 0.9162}
# {'data_timestamp': 1717462135000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 2, 795802), 'rate': 0.9162}
# {'data_timestamp': 1717462142000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 3, 892210), 'rate': 0.9162}
# {'data_timestamp': 1717462142000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 5, 63878), 'rate': 0.9162}
# {'data_timestamp': 1717462142000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 6, 166626), 'rate': 0.9162}
# {'data_timestamp': 1717462142000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 7, 286552), 'rate': 0.9162}
# {'data_timestamp': 1717462142000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 8, 394161), 'rate': 0.9162}
# {'data_timestamp': 1717462142000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 9, 494710), 'rate': 0.9162}
# {'data_timestamp': 1717462142000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 10, 610846), 'rate': 0.9162}
# {'data_timestamp': 1717462150000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 11, 720760), 'rate': 0.9162}
# {'data_timestamp': 1717462150000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 12, 821018), 'rate': 0.9162}
# {'data_timestamp': 1717462150000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 13, 928047), 'rate': 0.9162}
# {'data_timestamp': 1717462150000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 15, 29558), 'rate': 0.9162}
# {'data_timestamp': 1717462155000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 16, 136375), 'rate': 0.9163}
# {'data_timestamp': 1717462155000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 17, 237416), 'rate': 0.9163}
# {'data_timestamp': 1717462158000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 18, 339993), 'rate': 0.9163}
# {'data_timestamp': 1717462158000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 19, 485664), 'rate': 0.9163}
# {'data_timestamp': 1717462158000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 20, 728796), 'rate': 0.9163}
# {'data_timestamp': 1717462158000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 21, 836301), 'rate': 0.9163}
# {'data_timestamp': 1717462162000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 22, 931962), 'rate': 0.9161}
# {'data_timestamp': 1717462162000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 24, 44683), 'rate': 0.9161}
# {'data_timestamp': 1717462164000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 25, 149547), 'rate': 0.9163}
# {'data_timestamp': 1717462164000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 26, 254318), 'rate': 0.9163}
# {'data_timestamp': 1717462164000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 27, 356576), 'rate': 0.9163}
# {'data_timestamp': 1717462164000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 28, 475170), 'rate': 0.9163}
# {'data_timestamp': 1717462164000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 29, 579336), 'rate': 0.9163}
# {'data_timestamp': 1717462164000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 30, 679230), 'rate': 0.9163}
# {'data_timestamp': 1717462164000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 31, 806180), 'rate': 0.9163}
# {'data_timestamp': 1717462164000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 32, 914096), 'rate': 0.9163}
# {'data_timestamp': 1717462173000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 34, 16126), 'rate': 0.9163}
# {'data_timestamp': 1717462173000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 35, 127538), 'rate': 0.9163}
# {'data_timestamp': 1717462173000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 36, 302839), 'rate': 0.9163}
# {'data_timestamp': 1717462173000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 37, 402553), 'rate': 0.9163}
# {'data_timestamp': 1717462173000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 38, 506295), 'rate': 0.9163}
# {'data_timestamp': 1717462173000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 39, 625673), 'rate': 0.9163}
# {'data_timestamp': 1717462173000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 40, 731693), 'rate': 0.9163}
# {'data_timestamp': 1717462173000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 42, 132965), 'rate': 0.9163}
# {'data_timestamp': 1717462173000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 43, 242472), 'rate': 0.9163}
# {'data_timestamp': 1717462173000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 44, 344193), 'rate': 0.9163}
# {'data_timestamp': 1717462185000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 45, 507965), 'rate': 0.9162}
# {'data_timestamp': 1717462185000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 46, 631187), 'rate': 0.9162}
# {'data_timestamp': 1717462185000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 47, 732709), 'rate': 0.9162}
# {'data_timestamp': 1717462188000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 48, 830889), 'rate': 0.9163}
# {'data_timestamp': 1717462188000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 49, 932341), 'rate': 0.9163}
# {'data_timestamp': 1717462190000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 51, 38953), 'rate': 0.9162}
# {'data_timestamp': 1717462190000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 52, 279866), 'rate': 0.9162}
# {'data_timestamp': 1717462190000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 53, 381195), 'rate': 0.9162}
# {'data_timestamp': 1717462190000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 54, 484460), 'rate': 0.9162}
# {'data_timestamp': 1717462195000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 55, 780191), 'rate': 0.9162}
# {'data_timestamp': 1717462196000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 56, 888719), 'rate': 0.9162}
# {'data_timestamp': 1717462197000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 58, 4872), 'rate': 0.9162}
# {'data_timestamp': 1717462197000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 49, 59, 195727), 'rate': 0.9162}
# {'data_timestamp': 1717462200000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 0, 303404), 'rate': 0.916}
# {'data_timestamp': 1717462200000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 1, 416873), 'rate': 0.916}
# {'data_timestamp': 1717462200000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 2, 517450), 'rate': 0.916}
# {'data_timestamp': 1717462203000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 3, 638137), 'rate': 0.9161}
# {'data_timestamp': 1717462203000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 4, 743807), 'rate': 0.9161}
# {'data_timestamp': 1717462203000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 5, 875714), 'rate': 0.9161}
# {'data_timestamp': 1717462203000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 6, 980859), 'rate': 0.9161}
# {'data_timestamp': 1717462207000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 8, 93131), 'rate': 0.9162}
# {'data_timestamp': 1717462207000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 9, 196380), 'rate': 0.9162}
# {'data_timestamp': 1717462207000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 10, 304493), 'rate': 0.9162}
# {'data_timestamp': 1717462207000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 11, 427827), 'rate': 0.9162}
# {'data_timestamp': 1717462207000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 12, 553077), 'rate': 0.9162}
# {'data_timestamp': 1717462207000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 13, 849919), 'rate': 0.9162}
# {'data_timestamp': 1717462207000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 14, 971103), 'rate': 0.9162}
# {'data_timestamp': 1717462215000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 16, 83232), 'rate': 0.9162}
# {'data_timestamp': 1717462215000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 17, 206180), 'rate': 0.9162}
# {'data_timestamp': 1717462215000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 18, 315714), 'rate': 0.9162}
# {'data_timestamp': 1717462218000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 19, 435100), 'rate': 0.9162}
# {'data_timestamp': 1717462220000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 20, 544485), 'rate': 0.916}
# {'data_timestamp': 1717462221000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 21, 657905), 'rate': 0.9162}
# {'data_timestamp': 1717462221000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 22, 774304), 'rate': 0.9162}
# {'data_timestamp': 1717462222000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 23, 900652), 'rate': 0.9162}
# {'data_timestamp': 1717462222000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 25, 8030), 'rate': 0.9162}
# {'data_timestamp': 1717462222000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 26, 109768), 'rate': 0.9162}
# {'data_timestamp': 1717462226000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 27, 228102), 'rate': 0.9162}
# {'data_timestamp': 1717462226000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 28, 479821), 'rate': 0.9162}
# {'data_timestamp': 1717462226000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 29, 680602), 'rate': 0.9162}
# {'data_timestamp': 1717462230000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 30, 810756), 'rate': 0.9159}
# {'data_timestamp': 1717462230000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 31, 921146), 'rate': 0.9159}
# {'data_timestamp': 1717462230000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 33, 44279), 'rate': 0.9159}
# {'data_timestamp': 1717462233000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 34, 126185), 'rate': 0.9162}
# {'data_timestamp': 1717462233000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 35, 248239), 'rate': 0.9162}
# {'data_timestamp': 1717462235000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 36, 359940), 'rate': 0.9162}
# {'data_timestamp': 1717462235000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 37, 458205), 'rate': 0.9162}
# {'data_timestamp': 1717462235000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 38, 578744), 'rate': 0.9162}
# {'data_timestamp': 1717462239000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 39, 675322), 'rate': 0.9162}
# {'data_timestamp': 1717462239000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 40, 791014), 'rate': 0.9162}
# {'data_timestamp': 1717462239000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 41, 895498), 'rate': 0.9162}
# {'data_timestamp': 1717462242000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 43, 8375), 'rate': 0.9162}
# {'data_timestamp': 1717462242000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 44, 163573), 'rate': 0.9162}
# {'data_timestamp': 1717462242000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 45, 417316), 'rate': 0.9162}
# {'data_timestamp': 1717462242000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 46, 531539), 'rate': 0.9162}
# {'data_timestamp': 1717462242000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 47, 628673), 'rate': 0.9162}
# {'data_timestamp': 1717462248000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 48, 743770), 'rate': 0.9162}
# {'data_timestamp': 1717462249000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 49, 851429), 'rate': 0.9162}
# {'data_timestamp': 1717462250000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 50, 958769), 'rate': 0.9162}
# {'data_timestamp': 1717462250000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 52, 57674), 'rate': 0.9162}
# {'data_timestamp': 1717462252000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 53, 236381), 'rate': 0.9162}
# {'data_timestamp': 1717462252000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 54, 353638), 'rate': 0.9162}
# {'data_timestamp': 1717462252000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 55, 457240), 'rate': 0.9162}
# {'data_timestamp': 1717462252000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 56, 584159), 'rate': 0.9162}
# {'data_timestamp': 1717462252000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 57, 683684), 'rate': 0.9162}
# {'data_timestamp': 1717462257000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 50, 58, 977079), 'rate': 0.9162}
# {'data_timestamp': 1717462257000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 0, 88126), 'rate': 0.9162}
# {'data_timestamp': 1717462260000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 1, 193343), 'rate': 0.9162}
# {'data_timestamp': 1717462260000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 2, 306873), 'rate': 0.9162}
# {'data_timestamp': 1717462262000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 3, 411840), 'rate': 0.9162}
# {'data_timestamp': 1717462264000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 4, 548902), 'rate': 0.9162}
# {'data_timestamp': 1717462264000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 5, 683151), 'rate': 0.9162}
# {'data_timestamp': 1717462265000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 6, 791982), 'rate': 0.9162}
# {'data_timestamp': 1717462267000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 7, 906912), 'rate': 0.9162}
# {'data_timestamp': 1717462267000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 9, 18173), 'rate': 0.9162}
# {'data_timestamp': 1717462267000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 10, 136870), 'rate': 0.9162}
# {'data_timestamp': 1717462267000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 11, 323626), 'rate': 0.9162}
# {'data_timestamp': 1717462267000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 12, 458037), 'rate': 0.9162}
# {'data_timestamp': 1717462273000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 13, 589420), 'rate': 0.9162}
# {'data_timestamp': 1717462273000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 14, 791461), 'rate': 0.9162}
# {'data_timestamp': 1717462273000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 15, 910315), 'rate': 0.9162}
# {'data_timestamp': 1717462276000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 17, 31181), 'rate': 0.9162}
# {'data_timestamp': 1717462276000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 18, 161231), 'rate': 0.9162}
# {'data_timestamp': 1717462278000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 19, 267940), 'rate': 0.9162}
# {'data_timestamp': 1717462279000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 20, 374840), 'rate': 0.9162}
# {'data_timestamp': 1717462279000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 21, 502576), 'rate': 0.9162}
# {'data_timestamp': 1717462279000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 22, 623122), 'rate': 0.9162}
# {'data_timestamp': 1717462279000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 23, 747560), 'rate': 0.9162}
# {'data_timestamp': 1717462279000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 24, 945143), 'rate': 0.9162}
# {'data_timestamp': 1717462285000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 26, 75514), 'rate': 0.9162}
# {'data_timestamp': 1717462285000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 27, 176713), 'rate': 0.9162}
# {'data_timestamp': 1717462287000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 28, 304316), 'rate': 0.9162}
# {'data_timestamp': 1717462287000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 29, 416158), 'rate': 0.9162}
# {'data_timestamp': 1717462287000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 30, 547556), 'rate': 0.9162}
# {'data_timestamp': 1717462290000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 31, 822671), 'rate': 0.9161}
# {'data_timestamp': 1717462292000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 32, 933266), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 34, 146707), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 35, 255004), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 36, 478682), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 37, 584915), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 38, 696677), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 39, 804982), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 40, 907087), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 42, 27191), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 43, 123033), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 44, 239209), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 45, 337323), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 46, 454770), 'rate': 0.9162}
# {'data_timestamp': 1717462293000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 47, 576120), 'rate': 0.9162}
# {'data_timestamp': 1717462308000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 48, 698179), 'rate': 0.9162}
# {'data_timestamp': 1717462309000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 49, 811887), 'rate': 0.9162}
# {'data_timestamp': 1717462309000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 50, 925723), 'rate': 0.9162}
# {'data_timestamp': 1717462310000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 52, 36587), 'rate': 0.9162}
# {'data_timestamp': 1717462312000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 53, 128307), 'rate': 0.9162}
# {'data_timestamp': 1717462312000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 54, 239774), 'rate': 0.9162}
# {'data_timestamp': 1717462312000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 55, 339467), 'rate': 0.9162}
# {'data_timestamp': 1717462315000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 56, 444860), 'rate': 0.916}
# {'data_timestamp': 1717462315000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 57, 556471), 'rate': 0.916}
# {'data_timestamp': 1717462315000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 58, 665319), 'rate': 0.916}
# {'data_timestamp': 1717462319000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 51, 59, 758664), 'rate': 0.9162}
# {'data_timestamp': 1717462319000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 0, 873237), 'rate': 0.9162}
# {'data_timestamp': 1717462319000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 1, 967552), 'rate': 0.9162}
# {'data_timestamp': 1717462319000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 3, 88749), 'rate': 0.9162}
# {'data_timestamp': 1717462323000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 4, 200477), 'rate': 0.9161}
# {'data_timestamp': 1717462323000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 5, 312409), 'rate': 0.9161}
# {'data_timestamp': 1717462323000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 6, 436285), 'rate': 0.9161}
# {'data_timestamp': 1717462323000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 7, 623594), 'rate': 0.9161}
# {'data_timestamp': 1717462327000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 8, 719819), 'rate': 0.9162}
# {'data_timestamp': 1717462327000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 9, 826213), 'rate': 0.9162}
# {'data_timestamp': 1717462329000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 11, 31292), 'rate': 0.9162}
# {'data_timestamp': 1717462332000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 12, 237510), 'rate': 0.9162}
# {'data_timestamp': 1717462332000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 13, 358501), 'rate': 0.9162}
# {'data_timestamp': 1717462334000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 14, 464021), 'rate': 0.9162}
# {'data_timestamp': 1717462334000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 15, 559580), 'rate': 0.9162}
# {'data_timestamp': 1717462336000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 16, 670409), 'rate': 0.9162}
# {'data_timestamp': 1717462336000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 17, 784542), 'rate': 0.9162}
# {'data_timestamp': 1717462338000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 18, 889408), 'rate': 0.9162}
# {'data_timestamp': 1717462339000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 20, 16248), 'rate': 0.9162}
# {'data_timestamp': 1717462339000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 21, 135931), 'rate': 0.9162}
# {'data_timestamp': 1717462341000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 22, 253434), 'rate': 0.9162}
# {'data_timestamp': 1717462342000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 23, 362231), 'rate': 0.9162}
# {'data_timestamp': 1717462342000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 24, 467183), 'rate': 0.9162}
# {'data_timestamp': 1717462342000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 25, 596084), 'rate': 0.9162}
# {'data_timestamp': 1717462345000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 26, 705742), 'rate': 0.9162}
# {'data_timestamp': 1717462345000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 27, 827579), 'rate': 0.9162}
# {'data_timestamp': 1717462345000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 28, 924278), 'rate': 0.9162}
# {'data_timestamp': 1717462345000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 30, 48645), 'rate': 0.9162}
# {'data_timestamp': 1717462345000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 31, 163658), 'rate': 0.9162}
# {'data_timestamp': 1717462345000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 32, 296465), 'rate': 0.9162}
# {'data_timestamp': 1717462345000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 33, 410699), 'rate': 0.9162}
# ===================End of first loop ===========================
# max_rate: 0.9163
# min_rate: 0.9159
# mean_value: 0.9161880877742972
# vol: 0.00043659157474059616
# {'data_timestamp': 1717462353000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 34, 555972), 'rate': 0.9162}
# {'data_timestamp': 1717462355000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 35, 672899), 'rate': 0.9162}
# {'data_timestamp': 1717462356000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 36, 779470), 'rate': 0.9162}
# {'data_timestamp': 1717462356000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 38, 35205), 'rate': 0.9162}
# {'data_timestamp': 1717462357000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 39, 153087), 'rate': 0.9162}
# {'data_timestamp': 1717462357000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 40, 246818), 'rate': 0.9162}
# {'data_timestamp': 1717462357000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 41, 348748), 'rate': 0.9162}
# {'data_timestamp': 1717462357000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 42, 454402), 'rate': 0.9162}
# {'data_timestamp': 1717462363000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 43, 568219), 'rate': 0.9162}
# {'data_timestamp': 1717462364000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 44, 722668), 'rate': 0.9162}
# {'data_timestamp': 1717462364000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 45, 842200), 'rate': 0.9162}
# {'data_timestamp': 1717462364000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 46, 936765), 'rate': 0.9162}
# {'data_timestamp': 1717462364000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 48, 51269), 'rate': 0.9162}
# {'data_timestamp': 1717462368000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 49, 190658), 'rate': 0.9162}
# {'data_timestamp': 1717462368000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 50, 312016), 'rate': 0.9162}
# {'data_timestamp': 1717462368000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 51, 425327), 'rate': 0.9162}
# {'data_timestamp': 1717462371000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 52, 518207), 'rate': 0.9162}
# {'data_timestamp': 1717462371000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 53, 641912), 'rate': 0.9162}
# {'data_timestamp': 1717462373000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 54, 745261), 'rate': 0.9162}
# {'data_timestamp': 1717462375000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 55, 850280), 'rate': 0.9162}
# {'data_timestamp': 1717462375000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 56, 949894), 'rate': 0.9162}
# {'data_timestamp': 1717462377000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 58, 56770), 'rate': 0.9162}
# {'data_timestamp': 1717462377000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 52, 59, 148868), 'rate': 0.9162}
# {'data_timestamp': 1717462377000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 0, 248132), 'rate': 0.9162}
# {'data_timestamp': 1717462377000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 1, 356921), 'rate': 0.9162}
# {'data_timestamp': 1717462377000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 2, 463323), 'rate': 0.9162}
# {'data_timestamp': 1717462377000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 3, 577370), 'rate': 0.9162}
# {'data_timestamp': 1717462383000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 5, 32979), 'rate': 0.9162}
# {'data_timestamp': 1717462383000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 6, 133895), 'rate': 0.9162}
# {'data_timestamp': 1717462383000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 7, 230581), 'rate': 0.9162}
# {'data_timestamp': 1717462383000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 8, 339365), 'rate': 0.9162}
# {'data_timestamp': 1717462383000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 9, 440929), 'rate': 0.9162}
# {'data_timestamp': 1717462383000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 10, 612075), 'rate': 0.9162}
# {'data_timestamp': 1717462383000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 11, 712834), 'rate': 0.9162}
# {'data_timestamp': 1717462392000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 12, 819688), 'rate': 0.9162}
# {'data_timestamp': 1717462392000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 13, 946475), 'rate': 0.9162}
# {'data_timestamp': 1717462393000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 15, 42683), 'rate': 0.9162}
# {'data_timestamp': 1717462393000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 16, 148253), 'rate': 0.9162}
# {'data_timestamp': 1717462393000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 17, 254458), 'rate': 0.9162}
# {'data_timestamp': 1717462393000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 18, 357252), 'rate': 0.9162}
# {'data_timestamp': 1717462398000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 19, 489855), 'rate': 0.9162}
# {'data_timestamp': 1717462400000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 20, 602506), 'rate': 0.9162}
# {'data_timestamp': 1717462401000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 21, 698435), 'rate': 0.9162}
# {'data_timestamp': 1717462401000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 22, 814982), 'rate': 0.9162}
# {'data_timestamp': 1717462401000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 23, 930820), 'rate': 0.9162}
# {'data_timestamp': 1717462401000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 25, 33707), 'rate': 0.9162}
# {'data_timestamp': 1717462405000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 26, 286904), 'rate': 0.9162}
# {'data_timestamp': 1717462406000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 27, 406460), 'rate': 0.9162}
# {'data_timestamp': 1717462408000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 28, 533457), 'rate': 0.9162}
# {'data_timestamp': 1717462408000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 29, 644343), 'rate': 0.9162}
# {'data_timestamp': 1717462408000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 30, 788644), 'rate': 0.9162}
# {'data_timestamp': 1717462408000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 31, 889836), 'rate': 0.9162}
# {'data_timestamp': 1717462412000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 32, 999559), 'rate': 0.9162}
# {'data_timestamp': 1717462413000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 34, 105018), 'rate': 0.9162}
# {'data_timestamp': 1717462414000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 35, 250073), 'rate': 0.9162}
# {'data_timestamp': 1717462414000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 36, 405315), 'rate': 0.9162}
# {'data_timestamp': 1717462414000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 37, 626695), 'rate': 0.9162}
# {'data_timestamp': 1717462414000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 38, 747141), 'rate': 0.9162}
# {'data_timestamp': 1717462419000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 39, 845608), 'rate': 0.9162}
# {'data_timestamp': 1717462419000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 40, 946391), 'rate': 0.9162}
# {'data_timestamp': 1717462421000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 42, 43023), 'rate': 0.9161}
# {'data_timestamp': 1717462422000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 43, 148817), 'rate': 0.9161}
# {'data_timestamp': 1717462422000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 44, 243711), 'rate': 0.9161}
# {'data_timestamp': 1717462422000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 45, 402650), 'rate': 0.9161}
# {'data_timestamp': 1717462426000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 46, 502396), 'rate': 0.916}
# {'data_timestamp': 1717462426000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 47, 597284), 'rate': 0.9161}
# {'data_timestamp': 1717462426000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 48, 700130), 'rate': 0.9161}
# {'data_timestamp': 1717462428000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 49, 918095), 'rate': 0.9161}
# {'data_timestamp': 1717462428000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 51, 16846), 'rate': 0.9161}
# {'data_timestamp': 1717462431000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 52, 104483), 'rate': 0.9161}
# {'data_timestamp': 1717462431000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 53, 212202), 'rate': 0.9161}
# {'data_timestamp': 1717462431000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 54, 357000), 'rate': 0.9161}
# {'data_timestamp': 1717462431000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 55, 594573), 'rate': 0.9161}
# {'data_timestamp': 1717462431000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 56, 713184), 'rate': 0.9161}
# {'data_timestamp': 1717462437000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 57, 809385), 'rate': 0.9161}
# {'data_timestamp': 1717462438000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 53, 58, 938596), 'rate': 0.9161}
# {'data_timestamp': 1717462439000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 54, 0, 40329), 'rate': 0.9161}
# {'data_timestamp': 1717462439000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 54, 1, 144601), 'rate': 0.9161}
# {'data_timestamp': 1717462439000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 54, 2, 386460), 'rate': 0.9161}
# {'data_timestamp': 1717462442000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 54, 3, 635603), 'rate': 0.9161}
# {'data_timestamp': 1717462444000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 54, 4, 746004), 'rate': 0.9161}
# {'data_timestamp': 1717462444000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 54, 5, 853882), 'rate': 0.9161}
# {'data_timestamp': 1717462446000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 54, 6, 965770), 'rate': 0.9161}
# {'data_timestamp': 1717462447000, 'rate_timestamp': datetime.datetime(2024, 6, 3, 20, 54, 8, 88307), 'rate': 0.9161}
# ...
# {'data_timestamp': 1717480306000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 46, 967500), 'rate': 0.9171}
# {'data_timestamp': 1717480307000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 48, 87800), 'rate': 0.9171}
# {'data_timestamp': 1717480307000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 49, 238006), 'rate': 0.9171}
# {'data_timestamp': 1717480309000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 50, 340697), 'rate': 0.917}
# {'data_timestamp': 1717480309000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 51, 436539), 'rate': 0.917}
# {'data_timestamp': 1717480309000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 52, 585868), 'rate': 0.917}
# {'data_timestamp': 1717480309000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 53, 713936), 'rate': 0.917}
# {'data_timestamp': 1717480309000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 54, 827374), 'rate': 0.917}
# {'data_timestamp': 1717480309000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 55, 941258), 'rate': 0.917}
# {'data_timestamp': 1717480316000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 57, 138173), 'rate': 0.9169}
# {'data_timestamp': 1717480316000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 58, 265175), 'rate': 0.9169}
# {'data_timestamp': 1717480318000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 51, 59, 365476), 'rate': 0.9168}
# {'data_timestamp': 1717480319000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 0, 468569), 'rate': 0.917}
# {'data_timestamp': 1717480321000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 1, 585428), 'rate': 0.917}
# {'data_timestamp': 1717480322000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 2, 703867), 'rate': 0.917}
# {'data_timestamp': 1717480323000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 3, 819613), 'rate': 0.917}
# {'data_timestamp': 1717480323000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 5, 43266), 'rate': 0.917}
# {'data_timestamp': 1717480323000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 6, 161344), 'rate': 0.917}
# {'data_timestamp': 1717480326000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 7, 277500), 'rate': 0.917}
# {'data_timestamp': 1717480326000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 8, 479826), 'rate': 0.917}
# {'data_timestamp': 1717480329000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 9, 595534), 'rate': 0.9171}
# {'data_timestamp': 1717480330000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 10, 708688), 'rate': 0.9171}
# {'data_timestamp': 1717480330000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 11, 819244), 'rate': 0.9171}
# {'data_timestamp': 1717480330000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 12, 943361), 'rate': 0.9171}
# {'data_timestamp': 1717480333000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 14, 64128), 'rate': 0.9169}
# {'data_timestamp': 1717480334000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 15, 167268), 'rate': 0.9171}
# {'data_timestamp': 1717480334000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 16, 273066), 'rate': 0.9171}
# {'data_timestamp': 1717480336000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 17, 398793), 'rate': 0.917}
# {'data_timestamp': 1717480337000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 18, 532531), 'rate': 0.9171}
# {'data_timestamp': 1717480338000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 19, 664123), 'rate': 0.9171}
# {'data_timestamp': 1717480340000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 20, 794497), 'rate': 0.9171}
# {'data_timestamp': 1717480341000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 21, 905837), 'rate': 0.9171}
# {'data_timestamp': 1717480342000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 23, 11886), 'rate': 0.9171}
# {'data_timestamp': 1717480342000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 24, 103595), 'rate': 0.9171}
# {'data_timestamp': 1717480342000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 25, 398612), 'rate': 0.9171}
# {'data_timestamp': 1717480342000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 26, 503684), 'rate': 0.9171}
# {'data_timestamp': 1717480347000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 27, 635317), 'rate': 0.9171}
# {'data_timestamp': 1717480348000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 28, 761822), 'rate': 0.917}
# {'data_timestamp': 1717480349000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 29, 859521), 'rate': 0.9171}
# {'data_timestamp': 1717480349000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 31, 21637), 'rate': 0.9171}
# {'data_timestamp': 1717480349000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 32, 139476), 'rate': 0.9171}
# {'data_timestamp': 1717480349000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 33, 304966), 'rate': 0.9171}
# {'data_timestamp': 1717480349000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 34, 719131), 'rate': 0.9171}
# {'data_timestamp': 1717480349000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 35, 825651), 'rate': 0.9171}
# {'data_timestamp': 1717480356000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 36, 937385), 'rate': 0.917}
# {'data_timestamp': 1717480356000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 38, 64147), 'rate': 0.917}
# {'data_timestamp': 1717480358000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 39, 168493), 'rate': 0.9168}
# {'data_timestamp': 1717480359000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 40, 355789), 'rate': 0.9171}
# {'data_timestamp': 1717480361000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 41, 470802), 'rate': 0.917}
# {'data_timestamp': 1717480361000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 42, 597727), 'rate': 0.917}
# {'data_timestamp': 1717480361000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 43, 705230), 'rate': 0.917}
# {'data_timestamp': 1717480364000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 44, 848716), 'rate': 0.9171}
# {'data_timestamp': 1717480365000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 45, 956993), 'rate': 0.9171}
# {'data_timestamp': 1717480366000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 47, 68230), 'rate': 0.9171}
# {'data_timestamp': 1717480367000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 48, 211729), 'rate': 0.917}
# {'data_timestamp': 1717480367000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 49, 313933), 'rate': 0.917}
# {'data_timestamp': 1717480367000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 50, 422100), 'rate': 0.917}
# {'data_timestamp': 1717480367000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 51, 583892), 'rate': 0.917}
# {'data_timestamp': 1717480372000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 52, 946999), 'rate': 0.917}
# {'data_timestamp': 1717480372000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 54, 61425), 'rate': 0.917}
# {'data_timestamp': 1717480372000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 55, 161841), 'rate': 0.917}
# {'data_timestamp': 1717480372000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 56, 280050), 'rate': 0.917}
# {'data_timestamp': 1717480372000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 57, 406406), 'rate': 0.917}
# {'data_timestamp': 1717480372000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 58, 525551), 'rate': 0.917}
# {'data_timestamp': 1717480379000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 52, 59, 639343), 'rate': 0.9168}
# {'data_timestamp': 1717480379000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 53, 0, 849653), 'rate': 0.9168}
# {'data_timestamp': 1717480380000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 53, 1, 996701), 'rate': 0.9171}
# {'data_timestamp': 1717480382000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 53, 3, 392321), 'rate': 0.9171}
# {'data_timestamp': 1717480383000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 53, 4, 516901), 'rate': 0.9169}
# {'data_timestamp': 1717480383000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 53, 5, 619966), 'rate': 0.9169}
# {'data_timestamp': 1717480386000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 53, 6, 729986), 'rate': 0.917}
# {'data_timestamp': 1717480387000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 53, 7, 841073), 'rate': 0.9171}
# {'data_timestamp': 1717480387000, 'rate_timestamp': datetime.datetime(2024, 6, 4, 1, 53, 8, 951975), 'rate': 0.9171}
# Keltner Upper Bands for period 49:
# n=1, Upper Band=0.9170207782133448
# n=2, Upper Band=0.9170316838152239
# n=3, Upper Band=0.917042589417103
# n=4, Upper Band=0.9170534950189821
# n=5, Upper Band=0.9170644006208614
# n=6, Upper Band=0.9170753062227405
# n=7, Upper Band=0.9170862118246196
# n=8, Upper Band=0.9170971174264987
# n=9, Upper Band=0.9171080230283778
# n=10, Upper Band=0.9171189286302569
# n=11, Upper Band=0.917129834232136
# n=12, Upper Band=0.9171407398340151
# n=13, Upper Band=0.9171516454358943
# n=14, Upper Band=0.9171625510377734
# n=15, Upper Band=0.9171734566396526
# n=16, Upper Band=0.9171843622415317
# n=17, Upper Band=0.9171952678434108
# n=18, Upper Band=0.9172061734452899
# n=19, Upper Band=0.917217079047169
# n=20, Upper Band=0.9172279846490481
# n=21, Upper Band=0.9172388902509273
# n=22, Upper Band=0.9172497958528064
# n=23, Upper Band=0.9172607014546855
# n=24, Upper Band=0.9172716070565646
# n=25, Upper Band=0.9172825126584437
# n=26, Upper Band=0.9172934182603228
# n=27, Upper Band=0.917304323862202
# n=28, Upper Band=0.9173152294640811
# n=29, Upper Band=0.9173261350659602
# n=30, Upper Band=0.9173370406678394
# n=31, Upper Band=0.9173479462697185
# n=32, Upper Band=0.9173588518715976
# n=33, Upper Band=0.9173697574734767
# n=34, Upper Band=0.9173806630753558
# n=35, Upper Band=0.9173915686772349
# n=36, Upper Band=0.917402474279114
# n=37, Upper Band=0.9174133798809931
# n=38, Upper Band=0.9174242854828724
# n=39, Upper Band=0.9174351910847515
# n=40, Upper Band=0.9174460966866306
# n=41, Upper Band=0.9174570022885097
# n=42, Upper Band=0.9174679078903888
# n=43, Upper Band=0.9174788134922679
# n=44, Upper Band=0.917489719094147
# n=45, Upper Band=0.9175006246960261
# n=46, Upper Band=0.9175115302979053
# n=47, Upper Band=0.9175224358997844
# n=48, Upper Band=0.9175333415016635
# n=49, Upper Band=0.9175442471035427
# n=50, Upper Band=0.9175551527054218
# n=51, Upper Band=0.9175660583073009
# n=52, Upper Band=0.91757696390918
# n=53, Upper Band=0.9175878695110591
# n=54, Upper Band=0.9175987751129382
# n=55, Upper Band=0.9176096807148174
# n=56, Upper Band=0.9176205863166965
# n=57, Upper Band=0.9176314919185756
# n=58, Upper Band=0.9176423975204547
# n=59, Upper Band=0.9176533031223338
# n=60, Upper Band=0.917664208724213
# n=61, Upper Band=0.9176751143260921
# n=62, Upper Band=0.9176860199279712
# n=63, Upper Band=0.9176969255298504
# n=64, Upper Band=0.9177078311317295
# n=65, Upper Band=0.9177187367336086
# n=66, Upper Band=0.9177296423354877
# n=67, Upper Band=0.9177405479373668
# n=68, Upper Band=0.9177514535392459
# n=69, Upper Band=0.917762359141125
# n=70, Upper Band=0.9177732647430041
# n=71, Upper Band=0.9177841703448834
# n=72, Upper Band=0.9177950759467625
# n=73, Upper Band=0.9178059815486416
# n=74, Upper Band=0.9178168871505207
# n=75, Upper Band=0.9178277927523998
# n=76, Upper Band=0.9178386983542789
# n=77, Upper Band=0.917849603956158
# n=78, Upper Band=0.9178605095580371
# n=79, Upper Band=0.9178714151599162
# n=80, Upper Band=0.9178823207617954
# n=81, Upper Band=0.9178932263636745
# n=82, Upper Band=0.9179041319655536
# n=83, Upper Band=0.9179150375674328
# n=84, Upper Band=0.9179259431693119
# n=85, Upper Band=0.917936848771191
# n=86, Upper Band=0.9179477543730701
# n=87, Upper Band=0.9179586599749492
# n=88, Upper Band=0.9179695655768284
# n=89, Upper Band=0.9179804711787075
# n=90, Upper Band=0.9179913767805866
# n=91, Upper Band=0.9180022823824657
# n=92, Upper Band=0.9180131879843448
# n=93, Upper Band=0.9180240935862239
# n=94, Upper Band=0.918034999188103
# n=95, Upper Band=0.9180459047899822
# n=96, Upper Band=0.9180568103918614
# n=97, Upper Band=0.9180677159937405
# n=98, Upper Band=0.9180786215956196
# n=99, Upper Band=0.9180895271974987
# n=100, Upper Band=0.9181004327993778
# Keltner Lower Bands for period 49:
# n=1, Lower Band=0.9170207782133448
# n=2, Lower Band=0.9170316838152239
# n=3, Lower Band=0.917042589417103
# n=4, Lower Band=0.9170534950189821
# n=5, Lower Band=0.9170644006208614
# n=6, Lower Band=0.9170753062227405
# n=7, Lower Band=0.9170862118246196
# n=8, Lower Band=0.9170971174264987
# n=9, Lower Band=0.9171080230283778
# n=10, Lower Band=0.9171189286302569
# n=11, Lower Band=0.917129834232136
# n=12, Lower Band=0.9171407398340151
# n=13, Lower Band=0.9171516454358943
# n=14, Lower Band=0.9171625510377734
# n=15, Lower Band=0.9171734566396526
# n=16, Lower Band=0.9171843622415317
# n=17, Lower Band=0.9171952678434108
# n=18, Lower Band=0.9172061734452899
# n=19, Lower Band=0.917217079047169
# n=20, Lower Band=0.9172279846490481
# n=21, Lower Band=0.9172388902509273
# n=22, Lower Band=0.9172497958528064
# n=23, Lower Band=0.9172607014546855
# n=24, Lower Band=0.9172716070565646
# n=25, Lower Band=0.9172825126584437
# n=26, Lower Band=0.9172934182603228
# n=27, Lower Band=0.917304323862202
# n=28, Lower Band=0.9173152294640811
# n=29, Lower Band=0.9173261350659602
# n=30, Lower Band=0.9173370406678394
# n=31, Lower Band=0.9173479462697185
# n=32, Lower Band=0.9173588518715976
# n=33, Lower Band=0.9173697574734767
# n=34, Lower Band=0.9173806630753558
# n=35, Lower Band=0.9173915686772349
# n=36, Lower Band=0.917402474279114
# n=37, Lower Band=0.9174133798809931
# n=38, Lower Band=0.9174242854828724
# n=39, Lower Band=0.9174351910847515
# n=40, Lower Band=0.9174460966866306
# n=41, Lower Band=0.9174570022885097
# n=42, Lower Band=0.9174679078903888
# n=43, Lower Band=0.9174788134922679
# n=44, Lower Band=0.917489719094147
# n=45, Lower Band=0.9175006246960261
# n=46, Lower Band=0.9175115302979053
# n=47, Lower Band=0.9175224358997844
# n=48, Lower Band=0.9175333415016635
# n=49, Lower Band=0.9175442471035427
# n=50, Lower Band=0.9175551527054218
# n=51, Lower Band=0.9175660583073009
# n=52, Lower Band=0.91757696390918
# n=53, Lower Band=0.9175878695110591
# n=54, Lower Band=0.9175987751129382
# n=55, Lower Band=0.9176096807148174
# n=56, Lower Band=0.9176205863166965
# n=57, Lower Band=0.9176314919185756
# n=58, Lower Band=0.9176423975204547
# n=59, Lower Band=0.9176533031223338
# n=60, Lower Band=0.917664208724213
# n=61, Lower Band=0.9176751143260921
# n=62, Lower Band=0.9176860199279712
# n=63, Lower Band=0.9176969255298504
# n=64, Lower Band=0.9177078311317295
# n=65, Lower Band=0.9177187367336086
# n=66, Lower Band=0.9177296423354877
# n=67, Lower Band=0.9177405479373668
# n=68, Lower Band=0.9177514535392459
# n=69, Lower Band=0.917762359141125
# n=70, Lower Band=0.9177732647430041
# n=71, Lower Band=0.9177841703448834
# n=72, Lower Band=0.9177950759467625
# n=73, Lower Band=0.9178059815486416
# n=74, Lower Band=0.9178168871505207
# n=75, Lower Band=0.9178277927523998
# n=76, Lower Band=0.9178386983542789
# n=77, Lower Band=0.917849603956158
# n=78, Lower Band=0.9178605095580371
# n=79, Lower Band=0.9178714151599162
# n=80, Lower Band=0.9178823207617954
# n=81, Lower Band=0.9178932263636745
# n=82, Lower Band=0.9179041319655536
# n=83, Lower Band=0.9179150375674328
# n=84, Lower Band=0.9179259431693119
# n=85, Lower Band=0.917936848771191
# n=86, Lower Band=0.9179477543730701
# n=87, Lower Band=0.9179586599749492
# n=88, Lower Band=0.9179695655768284
# n=89, Lower Band=0.9179804711787075
# n=90, Lower Band=0.9179913767805866
# n=91, Lower Band=0.9180022823824657
# n=92, Lower Band=0.9180131879843448
# n=93, Lower Band=0.9180240935862239
# n=94, Lower Band=0.918034999188103
# n=95, Lower Band=0.9180459047899822
# n=96, Lower Band=0.9180568103918614
# n=97, Lower Band=0.9180677159937405
# n=98, Lower Band=0.9180786215956196
# n=99, Lower Band=0.9180895271974987
# n=100, Lower Band=0.9181004327993778
# Data has been saved to the Final DB (SQLite and MongoDB)
# ===================End of loop ===========================
# Number of Loops: 50
# Final fd: 122279.9999999682

# %%
#find all the data
records_data = session.query(FinalData).all()

with open('final_data_USDEUR.csv', 'w', newline='') as csvfile:
    fieldnames = ['id', 'data_timestamp', 'db_entry_timestamp', 'max_rate', 'min_rate', 'mean_rate', 'vol', 'fd']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for record in records_data:
        writer.writerow({
            'id': record.id,
            'data_timestamp': record.data_timestamp,
            'db_entry_timestamp': record.db_entry_timestamp,
            'max_rate': record.max_rate,
            'min_rate': record.min_rate,
            'mean_rate': record.mean_rate,
            'vol': record.vol,
            'fd': record.fd
        })

session.close()
